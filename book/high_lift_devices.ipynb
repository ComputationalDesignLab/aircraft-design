# %% [markdown]
# # High-Lift Devices
#
# This section talks about sizing of high-lift devices to meet maximum $C_L$ requirements for the example airplane.
#
# Typically, the goal of high-lift devices is to modified wing camber and area to enhance the lift generated by the wing.
#
# There are various types of high-lift devices.
#
# Commmon types of flaps: Plain, Split, Slotted, and Fowler Flaps
#
# control surfaces are usually plain flaps
#
# simple slotted flaps will be used
#
# LE devices are required to increase the stall angle of attack, TE devices reduce stall angle
#
# Refer figure 12.18 in Raymer for pictorial representation of various types of flaps.
#
# Type of high-lift devices
#
# Method used here is simplified analysis, empirical data, extrapolation from 2D test data
#
# Effect of flaps on CL
#
# Effect of flaps on Cd0
#
# Drag polar for TO and Landing scenario
#
# Raymer Chapter 12, Roskam Part 2 Chapter 7
#
# Table 8.3a - Aileron sizing, then decide on flaps

# %% [markdown]
# 15% Span is taken by fuselage
#
# Aileron in/out: 0.65 and 0.95 from Table 8.3b - Roskam Part 2, chord ratio is set to 25%
#
# Flap in/out: 0.2 and 0.6 based on wing planform, chord ratio is set to 25%

# %%
import numpy as np

A = 8
delta_Clmax = 1.3
taper_ratio = 0.4
# Sflapped = 
Sref = 134 # sq ft
quarter_chord = 0 # degree
hl_fraction = 0.75
sweep_hl = np.atan( np.tan(quarter_chord) - 4*(hl_fraction - 0.25)*(1 - taper_ratio)/(1 + taper_ratio)/A )

# sweep_hl = np.tan(quarter_chord) - 4*(hl_fraction - 0.25)*(1 - taper_ratio)/(1 + taper_ratio)/A

print(np.cos(sweep_hl))

delta_CLmax = 0.9*1.3*0.6

print(delta_CLmax)

print(0.7*delta_CLmax)
# Out:
# 0.994309153919809
# 0.7020000000000001
# 0.4914
