# %% [markdown]
# # Static roll and yaw stability derivatives
#
# Yaw derivative:
#
# $$
#     C_{n_{\beta}} = C_{n_{\beta_w}} + C_{n_{\beta_{fus}}} + C_{n_{\beta_v}}
# $$
#
# veritical force at prop is ignored
#
# Roll derivative:
#
# $$
#     C_{l_\beta} = C_{l_{\beta_w}} + C_{l_{\beta_v}}
# $$
