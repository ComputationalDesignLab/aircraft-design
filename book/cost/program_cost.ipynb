# %% [markdown]
# # Program cost
#
# This section computes RDTE and production cost for the example airplane and also performs a break-even analysis.
#
# 1st step: estimate man hours for engg, tooling and manufacturing
#
# 2nd step: estimate dollar amount for that cost
#
# 3rd step: price/unit, # of units for break-even
