# %% [markdown]
# # Static roll and yaw stability derivatives
#
# $$
#     C_{l_\beta} = C_{l_{\beta_w}} + C_{l_{\beta_v}}
# $$
#
# The main goal is to check for one-engine out operations
#
# It is difficult to perform lateral analysis at this stage of the design since it requries 6-DOF analysis and wind-tunnel data
